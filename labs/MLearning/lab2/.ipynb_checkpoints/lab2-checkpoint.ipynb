# %% [markdown]
# # Lab 2 - Clustering
# In this lab we look at clustering with k-means and GMMs. We will work on putting together the skeleton code to create the functionality of the algorithms, and then we will cluster the Fisher Iris dataset. We will finish by looking at the sklearn implementations of these algorithms.
#
# <b>Important note:</b>
#     Please do not edit the existing code snippets. Instead, add your functionality into the TODO sections. Read the entire skeleton structure first and think about how you should structure the code you are adding in carefully.
#
# There are <b>42</b> TODOs in this lab. It may seem like a lot but don't worry. Many are just selecting hyper-parameters and many of the visualisation TODOs are the same.

# %% [markdown]
# ## Task 2.1 - Data Exploration
# This task will load the data and explore the feature space of the observations. We will plot two feature dimensions against eachother, labeling them based on colour from the known class IDs.

# %%
# TODO: Do your package imports here.
import numpy as np
import matplotlib.pyplot as plt

# %%
# TODO: Load the data and the labels from file.
data = np.load('./Iris/Iris_data.npy')
labels = np.load('./Iris/Iris_labels.npy')
# TODO: Plot two feature dimensions against eachother, labeling the axes accordingly.
# TODO: Make sure the markers in the plot are coloured with their respective class labels.
plt.scatter(data[:, 0], data[:, 1], c=labels)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('True labels')
plt.show()

# %% [markdown]
# ## Task 2.2 - K-means Clustering
# The task here is to fill out the skeleton code in order to complete the k-means implementation. Follow the lecture notes and take some hints along the way. We first define a function to calculate the Euclidean distance between each of the cluster centres and the data, then we initialise our hyper-parameters and create a loop to fit our clusters to the data.
#
# ### K-Means algorithm:
#
# Setup: Select random initial set of k cluster centers
#
# Loop:
#
#     for i = 1 to maximum number of iterations
#         calculate distance from training points to cluster centroids
#         update class labels
#         recalculate centroid locations

# %%
# Definition of euclidean distance function between cluster centroid and matrix of datapoints
def euclidean_distance(k_centroids, datapoints):
    dists = np.zeros(shape=[datapoints.shape[0], k_centroids.shape[0]])
    
    for iK in range(0, k_centroids.shape[0]):
        centre = np.tile(k_centroids[iK, :], (datapoints.shape[0], 1))
        diff = centre - datapoints
        sum_of_squared_differences = np.zeros([datapoints.shape[0]])
        for i_dimension in range(0, k_centroids.shape[1]):
            sum_of_squared_differences += (diff[:, i_dimension]**2)
        dists[:,iK] = np.sqrt(sum_of_squared_differences)
        
    return dists

# %%
# TODO: Select a number of clusters.X
k = 2

# TODO: Select a number of iterations.X
n_iteration = 100

# TODO: Select cluster centroids.X
k_centroid = data[np.random.choice(data.shape[0], k), :]

# TODO: Loop over each iteration.X
for i in range(0, n_iteration):
    last_k_centroid = k_centroid
    
    #Calculate distances
    dists = euclidean_distance(k_centroid, data)
        
    #Reassign labels
    # TODO: Get cluster label based on distance from centroid. Hint: argmin.
    predicted_label = np.argmin(dists, axis=1)
    
    #Recalculate centroids
    new_centroid = np.zeros(shape=[k,data.shape[1]])
    # TODO: Loop over each cluster iK.X
    for iK in range(0,k):
        #Get all datapoints alocated to cluster iK
        # TODO: Slice into data with predicted_label.X
        cluster_data = data[predicted_label == iK, :]
        #Calculate the mean of this cluster
        # TODO: Calculate mean of datapoints.
        new_centroid[iK, :] = np.mean(cluster_data, axis=0)
        
    #Assign the new cluster centers
    k_centroid = new_centroid
        
    print('Iteration {0}: total update distance of centroids: {1}'.format(i, np.sum(np.abs(new_centroid - last_k_centroid))))
    
#Visualisation of model predictions
# TODO: Plot two feature dimensions against eachother, label with the predicted cluster labels.
# TODO: Plot the cluster centroids on top. Hint: use a different shaped marker with 'marker="x"'.
# TODO: Label axes correctly.
plt.scatter(data[:, 0], data[:, 1], c=predicted_label)
plt.scatter(last_k_centroid[:, 0], last_k_centroid[:, 1], marker='D')
plt.scatter(k_centroid[:, 0], k_centroid[:, 1], marker='x')
plt.title('Our implementation of k-Means')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()
# Out:
# Iteration 0: total update distance of centroids: 4.962499999999997
# Iteration 1: total update distance of centroids: 2.4405701754385993
# Iteration 2: total update distance of centroids: 2.294520001977012
# Iteration 3: total update distance of centroids: 1.6496680543707545
# Iteration 4: total update distance of centroids: 0.813813006916456
# Iteration 5: total update distance of centroids: 0.2251419073049094
# Iteration 6: total update distance of centroids: 0.0
# Iteration 7: total update distance of centroids: 0.0
# Iteration 8: total update distance of centroids: 0.0
# Iteration 9: total update distance of centroids: 0.0
# Iteration 10: total update distance of centroids: 0.0
# Iteration 11: total update distance of centroids: 0.0
# Iteration 12: total update distance of centroids: 0.0
# Iteration 13: total update distance of centroids: 0.0
# Iteration 14: total update distance of centroids: 0.0
# Iteration 15: total update distance of centroids: 0.0
# Iteration 16: total update distance of centroids: 0.0
# Iteration 17: total update distance of centroids: 0.0
# Iteration 18: total update distance of centroids: 0.0
# Iteration 19: total update distance of centroids: 0.0
# Iteration 20: total update distance of centroids: 0.0
# Iteration 21: total update distance of centroids: 0.0
# Iteration 22: total update distance of centroids: 0.0
# Iteration 23: total update distance of centroids: 0.0
# Iteration 24: total update distance of centroids: 0.0
# Iteration 25: total update distance of centroids: 0.0
# Iteration 26: total update distance of centroids: 0.0
# Iteration 27: total update distance of centroids: 0.0
# Iteration 28: total update distance of centroids: 0.0
# Iteration 29: total update distance of centroids: 0.0
# Iteration 30: total update distance of centroids: 0.0
# Iteration 31: total update distance of centroids: 0.0
# Iteration 32: total update distance of centroids: 0.0
# Iteration 33: total update distance of centroids: 0.0
# Iteration 34: total update distance of centroids: 0.0
# Iteration 35: total update distance of centroids: 0.0
# Iteration 36: total update distance of centroids: 0.0
# Iteration 37: total update distance of centroids: 0.0
# Iteration 38: total update distance of centroids: 0.0
# Iteration 39: total update distance of centroids: 0.0
# Iteration 40: total update distance of centroids: 0.0
# Iteration 41: total update distance of centroids: 0.0
# Iteration 42: total update distance of centroids: 0.0
# Iteration 43: total update distance of centroids: 0.0
# Iteration 44: total update distance of centroids: 0.0
# Iteration 45: total update distance of centroids: 0.0
# Iteration 46: total update distance of centroids: 0.0
# Iteration 47: total update distance of centroids: 0.0
# Iteration 48: total update distance of centroids: 0.0
# Iteration 49: total update distance of centroids: 0.0
# Iteration 50: total update distance of centroids: 0.0
# Iteration 51: total update distance of centroids: 0.0
# Iteration 52: total update distance of centroids: 0.0
# Iteration 53: total update distance of centroids: 0.0
# Iteration 54: total update distance of centroids: 0.0
# Iteration 55: total update distance of centroids: 0.0
# Iteration 56: total update distance of centroids: 0.0
# Iteration 57: total update distance of centroids: 0.0
# Iteration 58: total update distance of centroids: 0.0
# Iteration 59: total update distance of centroids: 0.0
# Iteration 60: total update distance of centroids: 0.0
# Iteration 61: total update distance of centroids: 0.0
# Iteration 62: total update distance of centroids: 0.0
# Iteration 63: total update distance of centroids: 0.0
# Iteration 64: total update distance of centroids: 0.0
# Iteration 65: total update distance of centroids: 0.0
# Iteration 66: total update distance of centroids: 0.0
# Iteration 67: total update distance of centroids: 0.0
# Iteration 68: total update distance of centroids: 0.0
# Iteration 69: total update distance of centroids: 0.0
# Iteration 70: total update distance of centroids: 0.0
# Iteration 71: total update distance of centroids: 0.0
# Iteration 72: total update distance of centroids: 0.0
# Iteration 73: total update distance of centroids: 0.0
# Iteration 74: total update distance of centroids: 0.0
# Iteration 75: total update distance of centroids: 0.0
# Iteration 76: total update distance of centroids: 0.0
# Iteration 77: total update distance of centroids: 0.0
# Iteration 78: total update distance of centroids: 0.0
# Iteration 79: total update distance of centroids: 0.0
# Iteration 80: total update distance of centroids: 0.0
# Iteration 81: total update distance of centroids: 0.0
# Iteration 82: total update distance of centroids: 0.0
# Iteration 83: total update distance of centroids: 0.0
# Iteration 84: total update distance of centroids: 0.0
# Iteration 85: total update distance of centroids: 0.0
# Iteration 86: total update distance of centroids: 0.0
# Iteration 87: total update distance of centroids: 0.0
# Iteration 88: total update distance of centroids: 0.0
# Iteration 89: total update distance of centroids: 0.0
# Iteration 90: total update distance of centroids: 0.0
# Iteration 91: total update distance of centroids: 0.0
# Iteration 92: total update distance of centroids: 0.0
# Iteration 93: total update distance of centroids: 0.0
# Iteration 94: total update distance of centroids: 0.0
# Iteration 95: total update distance of centroids: 0.0
# Iteration 96: total update distance of centroids: 0.0
# Iteration 97: total update distance of centroids: 0.0
# Iteration 98: total update distance of centroids: 0.0
# Iteration 99: total update distance of centroids: 0.0

# %% [markdown]
# ## Task 2.3 - Gaussian Mixture Models
# The task here is to fill out the skeleton code in order to complete the GMM implementation. Follow the lecture notes and take some hints along the way. We first define some functions for the algorithm, followed by initialisation of the parameters, and finally we implement the loop within which we fit our Gaussians to our data.
#
# ### GMM Algorithm:
# Setup: Initialise Gaussian distribution centroid, standard deviations and mixing coefficients using k-means coefficients.
#
# Loop:
#
#     Compute E-Step: calculate posteriors for the data given current Gaussian parameters
#     Compute M-Step: update model parameters

# %%
# TODO: Figure out which one is the E-Step and which is the M-Step.
#E
def multivariate_gaussian_density(x, mu, sig):
    size = x.shape[0]
    det = np.linalg.det(sig)
    norm_const = 1.0 / ((2*np.pi)**(size/2) * det **(1.0/2) )
    x_mu = x - mu
    inv = np.linalg.inv(sig)  
    result = np.e**(-(1.0/2) * (x_mu @ inv @ x_mu.T))
    
    return norm_const * result    
    
def likelihood(x,gCentroids, gSD, gMix):
    p = np.zeros([x.shape[0],gCentroids.shape[0]])
    p_total = np.zeros(x.shape[0])
    posteriors = np.zeros([x.shape[0],gCentroids.shape[0]])
    
    for iSample in range(0, x.shape[0]):
        for iCluster in range(0, gCentroids.shape[0]):
            p[iSample,iCluster] = multivariate_gaussian_density(x[iSample,:].T, gCentroids[iCluster,:], gSD[:,:,iCluster])
            p_total[iSample] = p_total[iSample] + p[iSample,iCluster] 
        
        for iCluster in range(0, gCentroids.shape[0]):
            posteriors[iSample, iCluster] = p[iSample, iCluster] / p_total[iSample]
            
    return posteriors    

#M
def update_params(data, posteriors, gMix, gSD, gCentroids):
    #Update mixing coefs
    clusterWeight = np.sum(posteriors,axis=0)
    # TODO: Use the equation on lab sheet to calculate the new mixing coefficients.
    newGMix = (1/posteriors.shape[0]) * clusterWeight
    
    
    #Update centroids
    newCentroids = np.zeros(gCentroids.shape)
    for iCluster in range(0, gMix.shape[0]):
        norm = np.expand_dims(posteriors[:, iCluster],axis=1)/np.sum(posteriors[:,iCluster])
        newCentroids[iCluster, :] = np.sum(norm * data, axis=0)

    #Update covariance matrices
    newGSD = np.zeros(gSD.shape)
    for c in range(0, gMix.shape[0]):
        running_sum = np.zeros(gSD.shape[0:2]) 
        for iData in range(0, data.shape[0]):
            mean_centred_data = (np.expand_dims(data[iData, :],axis=0) - newCentroids[c,:])
            running_sum += posteriors[iData, iCluster] * mean_centred_data * mean_centred_data.T
        running_sum = running_sum / np.sum(posteriors[:,iCluster],axis=0)
        newGSD[:,:,c] = running_sum

    return newGMix, newGSD, newCentroids

# %% [markdown]
# ### Initialise parameters
# Initialise the number of components, the number of iterations and the Gaussian parameters (mus, sigmas, mixings).

# %%
g = 2
nIteration = 200

cluster_centroids = np.zeros([g,data.shape[1]])
g_SD = np.zeros([data.shape[1],data.shape[1], g])
g_mix = np.zeros(g)

# TODO: Understand what is happening here. Hint: clustering part 2 lecture, slide 10.
for iCluster in range(0,g):
    data_in_cluster = data[predicted_label == iCluster, :]
    cluster_centroids[iCluster,:] = np.mean(data_in_cluster, axis=0)
    g_SD[:,:,iCluster] = np.cov(data_in_cluster.T)
    g_mix[iCluster] = data_in_cluster.shape[0] / data.shape[0]

# %% [markdown]
# ### Main loop of GMM fitting
# Loop over our iterations, computing steps E and M repeatedly.

# %%
for i in range(0, nIteration):
    #E-Step
    # TODO: Call E-Step function.
    posteriors = likelihood(data, cluster_centroids, g_SD, g_mix)

    #M-Step
    # TODO: Call M-Step function.
    g_mix, g_SD, cluster_centroids = update_params(data, posteriors, g_mix, g_SD, cluster_centroids)
        
    print('Iteration {0}'.format(i), end='\r')
    
    

#Predict labels
predicted_label = np.argmin(dists, axis=1)
# TODO: Get cluster label based on posterior. Hint: argmin.
    
#Visualisation of model predictions
# TODO: Plot two feature dimensions against eachother, label with the predicted cluster labels.
# TODO: Plot the cluster centroids on top. Hint: use a different shaped marker with 'marker="x"'.
# TODO: Label axes correctly.
plt.scatter(data[:, 0], data[:, 1], c=np.argmax(posteriors, axis=1))
plt.scatter(cluster_centroids[:, 0], cluster_centroids[:, 1], s=50, marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Our implementation of GMM')
plt.show()

#Visualisation of model posteriors
# TODO: Create a new figure with plt.figure()
# TODO: Plot two feature dimensions against eachother, label with the posteriors for a specific cluster.
# TODO: Plot the cluster centroids on top. Hint: use a different shaped marker with 'marker="x"'.
# TODO: Label axes correctly.
plt.scatter(data[:, 0], data[:, 1], c=posteriors[:,0])
plt.scatter(cluster_centroids[:, 0], cluster_centroids[:, 1], s=50, marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Posteriors of our GMM')
plt.show()
# Out:
# Iteration 199

# %% [markdown]
# # Using SciKit-Learn
# Here we will import SciKit-Learn and use the built-in API functionality to run k-Means clustering and GMM on the Fisher Iris data.
#
# Here we can use the <b>sklearn.cluster.KMeans</b> object. We need to define a number of clusters and then call the <b>fit</b> and <b>predict</b> methods.
#
# We can also use the <b>sklearn.mixture.GaussianMixture</b> object. We need to define a number of Guassians and then call the <b>fit</b> and <b>predict</b> methods.

# %%
import sklearn.cluster
import sklearn.mixture

# TODO: Create an instance of an sklearn.cluster KMeans object with k clusters
# TODO: Fit our data to the model with .fit(data)
# TODO: Predict data clusters with .predict(data)
# TODO: Plot two feature dimensions against eachother, label with the predicted cluster labels.
# TODO: Plot the cluster centroids on top. Hint: use a different shaped marker with 'marker="x"'.
# TODO: Label axes correctly.
k_means = sklearn.cluster.KMeans(4)
k_means.fit(data)
plt.scatter(data[:, 0], data[:, 1], c=k_means.predict(data))
plt.scatter(k_means.cluster_centers_[:, 0], k_means.cluster_centers_[:, 1], s=50, marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('sklearn implementation of GMMs')
plt.show() 


# TODO: create an instance of an sklearn.mixture GaussianMixture object with g clusters
# TODO: fit our data to the model with .fit(data)
# TODO: predict data clusters with .predict(data)
# TODO: Plot two feature dimensions against eachother, label with the predicted cluster labels.
# TODO: Plot the cluster centroids on top. Hint: use a different shaped marker with 'marker="x"'.
# TODO: Label axes correctly.
gaussian_mix = sklearn.mixture.GaussianMixture(4)
gaussian_mix.fit(data)
plt.scatter(data[:, 0], data[:, 1], c=gaussian_mix.predict(data))
plt.scatter(gaussian_mix.means_[:, 0], gaussian_mix.means_[:, 1], s=50, marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('sklearn implementation of GMMs')
plt.show()
